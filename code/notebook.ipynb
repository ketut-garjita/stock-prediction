# %% [markdown]
# ## Create Dataset using yfinance for :
# - ADRO.JK (Energy Company)
# - BBCA.JK (Banking)
# - TLKM.JK (Telecommunication)

# %%
# Create Dataset

import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta

# Three Indonesia Corp which different sectors listed in Yahoo Finance
ticker_symbols = ['ADRO.JK', 'BBCA.JK', 'TLKM.JK']

# Define start and end dates
# START_DATE = (datetime.today() - timedelta(days=100)).strftime('%Y-%m-%d')
# CURRENT_DATE = datetime.today().strftime('%Y-%m-%d')
START_DATE = "2020-01-01"
END_DATE = datetime.today().strftime('%Y-%m-%d')

# Join ticker symbols into a single string separated by comma
tickers = ",".join(ticker_symbols)

# Download data from Yahoo Finance
try:
    data = yf.download(tickers, start=START_DATE, end=END_DATE, group_by='ticker', interval='1d')
except yf.exceptions.YFTzMissingError as e:
    print(f"Failed downloads: {e.args[0]}")
    # Handle invalid tickers here, e.g., remove them from the list and retry

# Creaate DataFrame
data = pd.DataFrame(data)
data
# Out:
# [*********************100%***********************]  3 of 3 completed
# Ticker                    TLKM.JK                                       \
# Price                        Open    High     Low   Close    Adj Close
# Date
# 2020-01-02 00:00:00+00:00  3970.0  4000.0  3900.0  3910.0  3090.177979
# 2020-01-03 00:00:00+00:00  3960.0  3980.0  3930.0  3980.0  3145.500732
# 2020-01-06 00:00:00+00:00  3930.0  3970.0  3930.0  3960.0  3129.694336
# 2020-01-07 00:00:00+00:00  3930.0  3970.0  3920.0  3940.0  3113.887695
# 2020-01-08 00:00:00+00:00  3920.0  3950.0  3900.0  3900.0  3082.274658
# ...                           ...     ...     ...     ...          ...
# 2024-11-14 00:00:00+00:00  2550.0  2590.0  2530.0  2530.0  2530.000000
# 2024-11-15 00:00:00+00:00  2500.0  2580.0  2500.0  2540.0  2540.000000
# 2024-11-18 00:00:00+00:00  2540.0  2610.0  2520.0  2590.0  2590.000000
# 2024-11-19 00:00:00+00:00  2610.0  2850.0  2590.0  2780.0  2780.000000
# 2024-11-20 00:00:00+00:00  2740.0  2750.0  2640.0  2680.0  2680.000000
#
# Ticker                               ADRO.JK                          \
# Price                         Volume    Open    High     Low   Close
# Date
# 2020-01-02 00:00:00+00:00   52094000  1555.0  1555.0  1490.0  1495.0
# 2020-01-03 00:00:00+00:00   70032900  1460.0  1470.0  1425.0  1465.0
# 2020-01-06 00:00:00+00:00   42908900  1455.0  1515.0  1450.0  1465.0
# 2020-01-07 00:00:00+00:00   51837600  1480.0  1540.0  1460.0  1540.0
# 2020-01-08 00:00:00+00:00   52402600  1530.0  1535.0  1505.0  1505.0
# ...                              ...     ...     ...     ...     ...
# 2024-11-14 00:00:00+00:00  185269500  3940.0  3950.0  3830.0  3830.0
# 2024-11-15 00:00:00+00:00  103680400  3830.0  3940.0  3790.0  3920.0
# 2024-11-18 00:00:00+00:00  119481300  3920.0  3920.0  3670.0  3700.0
# 2024-11-19 00:00:00+00:00  275670300  3720.0  3800.0  3670.0  3710.0
# 2024-11-20 00:00:00+00:00  150242900  3710.0  3750.0  3660.0  3690.0
#
# Ticker                                             BBCA.JK                    \
# Price                        Adj Close     Volume     Open     High      Low
# Date
# 2020-01-02 00:00:00+00:00   835.632263   76612000   6695.0   6780.0   6680.0
# 2020-01-03 00:00:00+00:00   856.372192  117795600   6750.0   6800.0   6725.0
# 2020-01-06 00:00:00+00:00   856.372192   61423200   6720.0   6750.0   6690.0
# 2020-01-07 00:00:00+00:00   900.213806   74336500   6735.0   6770.0   6730.0
# 2020-01-08 00:00:00+00:00   879.754395   55121100   6670.0   6745.0   6670.0
# ...                                ...        ...      ...      ...      ...
# 2024-11-14 00:00:00+00:00  3830.000000   84790900  10125.0  10175.0  10050.0
# 2024-11-15 00:00:00+00:00  3920.000000   83361300  10050.0  10275.0  10050.0
# 2024-11-18 00:00:00+00:00  3700.000000  256319600  10075.0  10125.0  10000.0
# 2024-11-19 00:00:00+00:00  3710.000000  107023300   9900.0  10025.0   9900.0
# 2024-11-20 00:00:00+00:00  3690.000000   80247300  10025.0  10150.0  10000.0
#
# Ticker
# Price                        Close     Adj Close    Volume
# Date
# 2020-01-02 00:00:00+00:00   6690.0   6000.032227  49445000
# 2020-01-03 00:00:00+00:00   6800.0   6098.687500  47755500
# 2020-01-06 00:00:00+00:00   6735.0   6040.391602  27300000
# 2020-01-07 00:00:00+00:00   6740.0   6044.875977  45022500
# 2020-01-08 00:00:00+00:00   6680.0   5991.063965  53692500
# ...                            ...           ...       ...
# 2024-11-14 00:00:00+00:00  10100.0  10049.875977  56381400
# 2024-11-15 00:00:00+00:00  10175.0  10124.503906  63598200
# 2024-11-18 00:00:00+00:00  10000.0   9950.372070  65716200
# 2024-11-19 00:00:00+00:00   9925.0   9875.744141  85295300
# 2024-11-20 00:00:00+00:00  10075.0  10025.000000  58584400
#
# [1186 rows x 18 columns]

# %%
data.shape
# Out:
# (1186, 18)

# %%
# Check for any missing values
print(data.isnull().sum())
# Out:
# Ticker   Price
# TLKM.JK  Open         0
#          High         0
#          Low          0
#          Close        0
#          Adj Close    0
#          Volume       0
# ADRO.JK  Open         0
#          High         0
#          Low          0
#          Close        0
#          Adj Close    0
#          Volume       0
# BBCA.JK  Open         0
#          High         0
#          Low          0
#          Close        0
#          Adj Close    0
#          Volume       0
# dtype: int64

# %%
# Data Cleaning and Preprocessing
data = data.dropna()

# %%
# Check for any missing values
print(data.isnull().sum())
# Out:
# Ticker   Price
# TLKM.JK  Open         0
#          High         0
#          Low          0
#          Close        0
#          Adj Close    0
#          Volume       0
# ADRO.JK  Open         0
#          High         0
#          Low          0
#          Close        0
#          Adj Close    0
#          Volume       0
# BBCA.JK  Open         0
#          High         0
#          Low          0
#          Close        0
#          Adj Close    0
#          Volume       0
# dtype: int64

# %%
data.shape
# Out:
# (1186, 18)

# %%
data
# Out:
# Ticker                    TLKM.JK                                       \
# Price                        Open    High     Low   Close    Adj Close
# Date
# 2020-01-02 00:00:00+00:00  3970.0  4000.0  3900.0  3910.0  3090.177979
# 2020-01-03 00:00:00+00:00  3960.0  3980.0  3930.0  3980.0  3145.500732
# 2020-01-06 00:00:00+00:00  3930.0  3970.0  3930.0  3960.0  3129.694336
# 2020-01-07 00:00:00+00:00  3930.0  3970.0  3920.0  3940.0  3113.887695
# 2020-01-08 00:00:00+00:00  3920.0  3950.0  3900.0  3900.0  3082.274658
# ...                           ...     ...     ...     ...          ...
# 2024-11-14 00:00:00+00:00  2550.0  2590.0  2530.0  2530.0  2530.000000
# 2024-11-15 00:00:00+00:00  2500.0  2580.0  2500.0  2540.0  2540.000000
# 2024-11-18 00:00:00+00:00  2540.0  2610.0  2520.0  2590.0  2590.000000
# 2024-11-19 00:00:00+00:00  2610.0  2850.0  2590.0  2780.0  2780.000000
# 2024-11-20 00:00:00+00:00  2740.0  2750.0  2640.0  2680.0  2680.000000
#
# Ticker                               ADRO.JK                          \
# Price                         Volume    Open    High     Low   Close
# Date
# 2020-01-02 00:00:00+00:00   52094000  1555.0  1555.0  1490.0  1495.0
# 2020-01-03 00:00:00+00:00   70032900  1460.0  1470.0  1425.0  1465.0
# 2020-01-06 00:00:00+00:00   42908900  1455.0  1515.0  1450.0  1465.0
# 2020-01-07 00:00:00+00:00   51837600  1480.0  1540.0  1460.0  1540.0
# 2020-01-08 00:00:00+00:00   52402600  1530.0  1535.0  1505.0  1505.0
# ...                              ...     ...     ...     ...     ...
# 2024-11-14 00:00:00+00:00  185269500  3940.0  3950.0  3830.0  3830.0
# 2024-11-15 00:00:00+00:00  103680400  3830.0  3940.0  3790.0  3920.0
# 2024-11-18 00:00:00+00:00  119481300  3920.0  3920.0  3670.0  3700.0
# 2024-11-19 00:00:00+00:00  275670300  3720.0  3800.0  3670.0  3710.0
# 2024-11-20 00:00:00+00:00  150242900  3710.0  3750.0  3660.0  3690.0
#
# Ticker                                             BBCA.JK                    \
# Price                        Adj Close     Volume     Open     High      Low
# Date
# 2020-01-02 00:00:00+00:00   835.632263   76612000   6695.0   6780.0   6680.0
# 2020-01-03 00:00:00+00:00   856.372192  117795600   6750.0   6800.0   6725.0
# 2020-01-06 00:00:00+00:00   856.372192   61423200   6720.0   6750.0   6690.0
# 2020-01-07 00:00:00+00:00   900.213806   74336500   6735.0   6770.0   6730.0
# 2020-01-08 00:00:00+00:00   879.754395   55121100   6670.0   6745.0   6670.0
# ...                                ...        ...      ...      ...      ...
# 2024-11-14 00:00:00+00:00  3830.000000   84790900  10125.0  10175.0  10050.0
# 2024-11-15 00:00:00+00:00  3920.000000   83361300  10050.0  10275.0  10050.0
# 2024-11-18 00:00:00+00:00  3700.000000  256319600  10075.0  10125.0  10000.0
# 2024-11-19 00:00:00+00:00  3710.000000  107023300   9900.0  10025.0   9900.0
# 2024-11-20 00:00:00+00:00  3690.000000   80247300  10025.0  10150.0  10000.0
#
# Ticker
# Price                        Close     Adj Close    Volume
# Date
# 2020-01-02 00:00:00+00:00   6690.0   6000.032227  49445000
# 2020-01-03 00:00:00+00:00   6800.0   6098.687500  47755500
# 2020-01-06 00:00:00+00:00   6735.0   6040.391602  27300000
# 2020-01-07 00:00:00+00:00   6740.0   6044.875977  45022500
# 2020-01-08 00:00:00+00:00   6680.0   5991.063965  53692500
# ...                            ...           ...       ...
# 2024-11-14 00:00:00+00:00  10100.0  10049.875977  56381400
# 2024-11-15 00:00:00+00:00  10175.0  10124.503906  63598200
# 2024-11-18 00:00:00+00:00  10000.0   9950.372070  65716200
# 2024-11-19 00:00:00+00:00   9925.0   9875.744141  85295300
# 2024-11-20 00:00:00+00:00  10075.0  10025.000000  58584400
#
# [1186 rows x 18 columns]

# %%
# Summary of data types
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1186 entries, 2020-01-02 00:00:00+00:00 to 2024-11-20 00:00:00+00:00
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (TLKM.JK, Open)       1186 non-null   float64
#  1   (TLKM.JK, High)       1186 non-null   float64
#  2   (TLKM.JK, Low)        1186 non-null   float64
#  3   (TLKM.JK, Close)      1186 non-null   float64
#  4   (TLKM.JK, Adj Close)  1186 non-null   float64
#  5   (TLKM.JK, Volume)     1186 non-null   int64
#  6   (ADRO.JK, Open)       1186 non-null   float64
#  7   (ADRO.JK, High)       1186 non-null   float64
#  8   (ADRO.JK, Low)        1186 non-null   float64
#  9   (ADRO.JK, Close)      1186 non-null   float64
#  10  (ADRO.JK, Adj Close)  1186 non-null   float64
#  11  (ADRO.JK, Volume)     1186 non-null   int64
#  12  (BBCA.JK, Open)       1186 non-null   float64
#  13  (BBCA.JK, High)       1186 non-null   float64
#  14  (BBCA.JK, Low)        1186 non-null   float64
#  15  (BBCA.JK, Close)      1186 non-null   float64
#  16  (BBCA.JK, Adj Close)  1186 non-null   float64
#  17  (BBCA.JK, Volume)     1186 non-null   int64
# dtypes: float64(15), int64(3)
# memory usage: 176.0 KB
# None

# %%
# Get summary statistics for numerical columns
data.describe()
# Out:
# Ticker      TLKM.JK                                                      \
# Price          Open         High          Low        Close    Adj Close
# count   1186.000000  1186.000000  1186.000000  1186.000000  1186.000000
# mean    3631.854975  3671.930860  3588.229342  3628.608769  3229.965431
# std      518.612169   518.147201   517.538055   520.252458   514.504727
# min     2500.000000  2580.000000  2450.000000  2530.000000  2070.656494
# 25%     3190.000000  3230.000000  3140.000000  3172.500000  2815.622314
# 50%     3685.000000  3725.000000  3655.000000  3690.000000  3253.515747
# 75%     4020.000000  4050.000000  3980.000000  4017.500000  3672.674866
# max     4850.000000  4850.000000  4720.000000  4770.000000  4295.701172
#
# Ticker                    ADRO.JK                                         \
# Price         Volume         Open         High          Low        Close
# count   1.186000e+03  1186.000000  1186.000000  1186.000000  1186.000000
# mean    1.170443e+08  2290.425801  2327.525295  2251.572513  2287.251265
# std     7.806551e+07   941.399985   952.720272   930.038900   941.328865
# min     0.000000e+00   645.000000   670.000000   610.000000   645.000000
# 25%     6.944245e+07  1281.250000  1305.000000  1255.000000  1285.000000
# 50%     9.678180e+07  2425.000000  2460.000000  2395.000000  2425.000000
# 75%     1.410977e+08  2960.000000  3020.000000  2910.000000  2957.500000
# max     1.155861e+09  4140.000000  4300.000000  4080.000000  4140.000000
#
# Ticker                                  BBCA.JK                              \
# Price     Adj Close        Volume          Open          High           Low
# count   1186.000000  1.186000e+03   1186.000000   1186.000000   1186.000000
# mean    1779.216535  8.789672e+07   7871.994098   7943.039629   7798.612985
# std      928.208993  6.884276e+07   1483.189020   1483.297008   1487.335466
# min      377.037598  0.000000e+00   4450.000000   4800.000000   4325.000000
# 25%      789.839661  4.298208e+07   6556.250000   6591.250000   6500.000000
# 50%     2036.087280  7.007170e+07   7825.000000   7900.000000   7750.000000
# 75%     2414.809326  1.071960e+08   9068.750000   9125.000000   9025.000000
# max     4040.000000  5.399952e+08  10900.000000  10950.000000  10775.000000
#
# Ticker
# Price          Close     Adj Close        Volume
# count    1186.000000   1186.000000  1.186000e+03
# mean     7869.852445   7471.957449  8.816343e+07
# std      1487.506168   1626.707511  5.767026e+07
# min      4430.000000   3973.115479  0.000000e+00
# 25%      6565.000000   6028.191162  5.697070e+07
# 50%      7875.000000   7355.500488  7.536235e+07
# 75%      9068.750000   8784.651367  1.025686e+08
# max     10950.000000  10895.657227  7.564316e+08

# %% [markdown]
# ## EDA
# - Closing Price
# - Close Price and 30-Day Moving Average
# - Correlation between Stocks
# - Daily Return
# - Monthly and Yearly Average Closing Price

# %%
# EDA

import matplotlib.pyplot as plt

# Plot closing prices for each ticker
for ticker in ticker_symbols:
    plt.figure(figsize=(12, 6))
    data[ticker]['Close'].plot(title=f'{ticker} Closing Prices')
    plt.xlabel('Date')
    plt.ylabel('Closing Price')
    plt.show()

# %%
# Create a dictionary to hold the data with moving averages
ma_data = {}

for ticker in ticker_symbols:
    # Extract close prices for the ticker and calculate the 30-day moving average
    close_prices = data[ticker]['Close']
    ma_data[ticker] = pd.DataFrame({
        'Close': close_prices,
        'MA30': close_prices.rolling(window=30).mean()
    })

    # Plot close prices and 30-day moving average
    plt.figure(figsize=(12, 6))
    plt.plot(ma_data[ticker]['Close'], label='Closing Price')
    plt.plot(ma_data[ticker]['MA30'], label='30-Day Moving Average')
    plt.title(f'{ticker} - Close Price and 30-Day Moving Average')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %%
# Extract closing prices of all tickers
close_prices = pd.DataFrame({ticker: data[ticker]['Close'] for ticker in ticker_symbols})

# Calculate correlation matrix
correlation_matrix = close_prices.corr()
print("Correlation Matrix:\n", correlation_matrix)

# Heatmap of the correlation matrix
import seaborn as sns
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation between Stocks')
plt.show()
# Out:
# Correlation Matrix:
#            ADRO.JK   BBCA.JK   TLKM.JK
# ADRO.JK  1.000000  0.801337  0.436639
# BBCA.JK  0.801337  1.000000  0.211356
# TLKM.JK  0.436639  0.211356  1.000000

# %%
# Calculate daily returns
returns = close_prices.pct_change()

# Plot the daily returns
for ticker in ticker_symbols:
    plt.figure(figsize=(12, 6))
    returns[ticker].plot(title=f'{ticker} Daily Returns')
    plt.xlabel('Date')
    plt.ylabel('Daily Return')
    plt.show()

# Calculate volatility (standard deviation of returns)
volatility = returns.std()
print("Volatility:\n")
print(volatility)
# Out:
# Volatility:
#
# ADRO.JK    0.028283
# BBCA.JK    0.016204
# TLKM.JK    0.019040
# dtype: float64

# %%
# Resample to monthly mean
monthly_prices = close_prices.resample('ME').mean()
monthly_prices.plot(figsize=(14, 7), title='Monthly Average Closing Prices')
plt.xlabel('Date')
plt.ylabel('Monthly Average Price')
plt.show()

# Resample to yearly mean
yearly_prices = close_prices.resample('YE').mean()
yearly_prices.plot(figsize=(14, 7), title='Yearly Average Closing Prices')
plt.xlabel('Year')
plt.ylabel('Yearly Average Price')
plt.show()

# %% [markdown]
# ## Targets and Features Engineering

# %%
# All columns

print(data.columns)
# Therea are 2 columns for indexes: Ticker & Price
# Out:
# MultiIndex([('TLKM.JK',      'Open'),
#             ('TLKM.JK',      'High'),
#             ('TLKM.JK',       'Low'),
#             ('TLKM.JK',     'Close'),
#             ('TLKM.JK', 'Adj Close'),
#             ('TLKM.JK',    'Volume'),
#             ('ADRO.JK',      'Open'),
#             ('ADRO.JK',      'High'),
#             ('ADRO.JK',       'Low'),
#             ('ADRO.JK',     'Close'),
#             ('ADRO.JK', 'Adj Close'),
#             ('ADRO.JK',    'Volume'),
#             ('BBCA.JK',      'Open'),
#             ('BBCA.JK',      'High'),
#             ('BBCA.JK',       'Low'),
#             ('BBCA.JK',     'Close'),
#             ('BBCA.JK', 'Adj Close'),
#             ('BBCA.JK',    'Volume')],
#            names=['Ticker', 'Price'])

# %%
for ticker in ticker_symbols:
    ticker_feature_canditates = [col for col in data.columns if ticker in col and 'target' not in col]    
    print(ticker_feature_canditates)
# Out:
# [('ADRO.JK', 'Open'), ('ADRO.JK', 'High'), ('ADRO.JK', 'Low'), ('ADRO.JK', 'Close'), ('ADRO.JK', 'Adj Close'), ('ADRO.JK', 'Volume')]
# [('BBCA.JK', 'Open'), ('BBCA.JK', 'High'), ('BBCA.JK', 'Low'), ('BBCA.JK', 'Close'), ('BBCA.JK', 'Adj Close'), ('BBCA.JK', 'Volume')]
# [('TLKM.JK', 'Open'), ('TLKM.JK', 'High'), ('TLKM.JK', 'Low'), ('TLKM.JK', 'Close'), ('TLKM.JK', 'Adj Close'), ('TLKM.JK', 'Volume')]

# %%
# Define columns format 
data.columns = ['_'.join(col).replace(' ', '') for col in data.columns]
print(data.columns)
# Out:
# Index(['TLKM.JK_Open', 'TLKM.JK_High', 'TLKM.JK_Low', 'TLKM.JK_Close',
#        'TLKM.JK_AdjClose', 'TLKM.JK_Volume', 'ADRO.JK_Open', 'ADRO.JK_High',
#        'ADRO.JK_Low', 'ADRO.JK_Close', 'ADRO.JK_AdjClose', 'ADRO.JK_Volume',
#        'BBCA.JK_Open', 'BBCA.JK_High', 'BBCA.JK_Low', 'BBCA.JK_Close',
#        'BBCA.JK_AdjClose', 'BBCA.JK_Volume'],
#       dtype='object')

# %%
# Features and Target Engineering
# Add 1-day Moving Average (MA1) for each ticker
data = data.copy()  # Ensure data is a full copy, not a view

for ticker in ticker_symbols:
    close_col = f"{ticker}_Close"
    ma_col = f"{ticker}_MA1"
    data[ma_col] = data[close_col].rolling(window=1).mean()

print(data.columns)
# Out:
# Index(['TLKM.JK_Open', 'TLKM.JK_High', 'TLKM.JK_Low', 'TLKM.JK_Close',
#        'TLKM.JK_AdjClose', 'TLKM.JK_Volume', 'ADRO.JK_Open', 'ADRO.JK_High',
#        'ADRO.JK_Low', 'ADRO.JK_Close', 'ADRO.JK_AdjClose', 'ADRO.JK_Volume',
#        'BBCA.JK_Open', 'BBCA.JK_High', 'BBCA.JK_Low', 'BBCA.JK_Close',
#        'BBCA.JK_AdjClose', 'BBCA.JK_Volume', 'ADRO.JK_MA1', 'BBCA.JK_MA1',
#        'TLKM.JK_MA1'],
#       dtype='object')

# %%
# Features and Target Engineering
# Add 30-day Moving Average (MA30) for each ticker
data = data.copy()  # Ensure data is a full copy, not a view

for ticker in ticker_symbols:
    close_col = f"{ticker}_Close"
    ma_col = f"{ticker}_MA30"
    data[ma_col] = data[close_col].rolling(window=30).mean()

print(data.columns)
# Out:
# Index(['TLKM.JK_Open', 'TLKM.JK_High', 'TLKM.JK_Low', 'TLKM.JK_Close',
#        'TLKM.JK_AdjClose', 'TLKM.JK_Volume', 'ADRO.JK_Open', 'ADRO.JK_High',
#        'ADRO.JK_Low', 'ADRO.JK_Close', 'ADRO.JK_AdjClose', 'ADRO.JK_Volume',
#        'BBCA.JK_Open', 'BBCA.JK_High', 'BBCA.JK_Low', 'BBCA.JK_Close',
#        'BBCA.JK_AdjClose', 'BBCA.JK_Volume', 'ADRO.JK_MA1', 'BBCA.JK_MA1',
#        'TLKM.JK_MA1', 'ADRO.JK_MA30', 'BBCA.JK_MA30', 'TLKM.JK_MA30'],
#       dtype='object')

# %%
# Define Targets and Features for every Ticker

ticker_symbols = ['ADRO.JK', 'BBCA.JK', 'TLKM.JK']
targets = ['UpdDown', 'DailyResult', 'Votality']

for ticker in ticker_symbols:
    for target in targets:
        match target:
            case 'UpdDown':
                features = f'{ticker}_Open, {ticker}_Close, {ticker}_MA1'
            case 'DailyResult':
                features = f'{ticker}_Open, {ticker}_Close, {ticker}_MA1'
            case 'Votality':
                features = f'{ticker}_Open, {ticker}_Close, {ticker}_Volume, {ticker}_MA30'
            case _:
                features = "Unknown target"
        
        print(f'\nFeatures for {ticker} with target {target}:')
        print(features)
# Out:
# Features for ADRO.JK with target UpdDown:
# ADRO.JK_Open, ADRO.JK_Close, ADRO.JK_MA1
#
# Features for ADRO.JK with target DailyResult:
# ADRO.JK_Open, ADRO.JK_Close, ADRO.JK_MA1
#
# Features for ADRO.JK with target Votality:
# ADRO.JK_Open, ADRO.JK_Close, ADRO.JK_Volume, ADRO.JK_MA30
#
# Features for BBCA.JK with target UpdDown:
# BBCA.JK_Open, BBCA.JK_Close, BBCA.JK_MA1
#
# Features for BBCA.JK with target DailyResult:
# BBCA.JK_Open, BBCA.JK_Close, BBCA.JK_MA1
#
# Features for BBCA.JK with target Votality:
# BBCA.JK_Open, BBCA.JK_Close, BBCA.JK_Volume, BBCA.JK_MA30
#
# Features for TLKM.JK with target UpdDown:
# TLKM.JK_Open, TLKM.JK_Close, TLKM.JK_MA1
#
# Features for TLKM.JK with target DailyResult:
# TLKM.JK_Open, TLKM.JK_Close, TLKM.JK_MA1
#
# Features for TLKM.JK with target Votality:
# TLKM.JK_Open, TLKM.JK_Close, TLKM.JK_Volume, TLKM.JK_MA30
