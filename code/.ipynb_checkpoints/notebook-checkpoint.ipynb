# %% [markdown]
# ## Create Dataset using yfinance for :
# - ADRO.JK (Energy Company)
# - BBCA.JK (Banking)
# - TLKM.JK (Telecommunication)

# %%
# Create Dataset

import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta

# Three Indonesia Corp which different sectors listed in Yahoo Finance
ticker_symbols = ['ADRO.JK', 'BBCA.JK', 'TLKM.JK']

# Define start and end dates
# START_DATE = (datetime.today() - timedelta(days=100)).strftime('%Y-%m-%d')
# CURRENT_DATE = datetime.today().strftime('%Y-%m-%d')
START_DATE = "2020-01-01"
END_DATE = datetime.today().strftime('%Y-%m-%d')

# Join ticker symbols into a single string separated by comma
tickers = ",".join(ticker_symbols)

# Download data from Yahoo Finance
try:
    data = yf.download(tickers, start=START_DATE, end=END_DATE, group_by='ticker', interval='1d')
except yf.exceptions.YFTzMissingError as e:
    print(f"Failed downloads: {e.args[0]}")
    # Handle invalid tickers here, e.g., remove them from the list and retry

# Creaate DataFrame
data = pd.DataFrame(data)
data
# Out:
# [*********************100%***********************]  3 of 3 completed
# Ticker                    ADRO.JK                                       \
# Price                        Open    High     Low   Close    Adj Close
# Date
# 2020-01-02 00:00:00+00:00  1555.0  1555.0  1490.0  1495.0   835.632263
# 2020-01-03 00:00:00+00:00  1460.0  1470.0  1425.0  1465.0   856.372131
# 2020-01-06 00:00:00+00:00  1455.0  1515.0  1450.0  1465.0   856.372131
# 2020-01-07 00:00:00+00:00  1480.0  1540.0  1460.0  1540.0   900.213867
# 2020-01-08 00:00:00+00:00  1530.0  1535.0  1505.0  1505.0   879.754395
# ...                           ...     ...     ...     ...          ...
# 2024-11-12 00:00:00+00:00  3800.0  3900.0  3790.0  3820.0  3820.000000
# 2024-11-13 00:00:00+00:00  3950.0  4010.0  3870.0  3920.0  3920.000000
# 2024-11-14 00:00:00+00:00  3940.0  3950.0  3830.0  3830.0  3830.000000
# 2024-11-15 00:00:00+00:00  3830.0  3940.0  3790.0  3920.0  3920.000000
# 2024-11-18 00:00:00+00:00  3920.0  3920.0  3670.0  3700.0  3700.000000
#
# Ticker                                BBCA.JK                             \
# Price                         Volume     Open     High      Low    Close
# Date
# 2020-01-02 00:00:00+00:00   76612000   6695.0   6780.0   6680.0   6690.0
# 2020-01-03 00:00:00+00:00  117795600   6750.0   6800.0   6725.0   6800.0
# 2020-01-06 00:00:00+00:00   61423200   6720.0   6750.0   6690.0   6735.0
# 2020-01-07 00:00:00+00:00   74336500   6735.0   6770.0   6730.0   6740.0
# 2020-01-08 00:00:00+00:00   55121100   6670.0   6745.0   6670.0   6680.0
# ...                              ...      ...      ...      ...      ...
# 2024-11-12 00:00:00+00:00   85754000  10100.0  10225.0  10000.0  10150.0
# 2024-11-13 00:00:00+00:00  144865000  10225.0  10250.0  10150.0  10150.0
# 2024-11-14 00:00:00+00:00   84790900  10125.0  10175.0  10050.0  10100.0
# 2024-11-15 00:00:00+00:00   83361300  10050.0  10275.0  10050.0  10175.0
# 2024-11-18 00:00:00+00:00  256319600  10075.0  10125.0  10000.0  10000.0
#
# Ticker                                            TLKM.JK                  \
# Price                         Adj Close    Volume    Open    High     Low
# Date
# 2020-01-02 00:00:00+00:00   6029.958008  49445000  3970.0  4000.0  3900.0
# 2020-01-03 00:00:00+00:00   6129.104492  47755500  3960.0  3980.0  3930.0
# 2020-01-06 00:00:00+00:00   6070.518066  27300000  3930.0  3970.0  3930.0
# 2020-01-07 00:00:00+00:00   6075.024414  45022500  3930.0  3970.0  3920.0
# 2020-01-08 00:00:00+00:00   6020.944336  53692500  3920.0  3950.0  3900.0
# ...                                 ...       ...     ...     ...     ...
# 2024-11-12 00:00:00+00:00  10150.000000  80378500  2660.0  2670.0  2600.0
# 2024-11-13 00:00:00+00:00  10150.000000  62933100  2610.0  2630.0  2570.0
# 2024-11-14 00:00:00+00:00  10100.000000  56381400  2550.0  2590.0  2530.0
# 2024-11-15 00:00:00+00:00  10175.000000  63598200  2500.0  2580.0  2500.0
# 2024-11-18 00:00:00+00:00  10000.000000  65716200  2540.0  2610.0  2520.0
#
# Ticker
# Price                       Close    Adj Close     Volume
# Date
# 2020-01-02 00:00:00+00:00  3910.0  3090.177979   52094000
# 2020-01-03 00:00:00+00:00  3980.0  3145.500977   70032900
# 2020-01-06 00:00:00+00:00  3960.0  3129.694092   42908900
# 2020-01-07 00:00:00+00:00  3940.0  3113.887939   51837600
# 2020-01-08 00:00:00+00:00  3900.0  3082.274658   52402600
# ...                           ...          ...        ...
# 2024-11-12 00:00:00+00:00  2600.0  2600.000000  215910600
# 2024-11-13 00:00:00+00:00  2580.0  2580.000000  142812600
# 2024-11-14 00:00:00+00:00  2530.0  2530.000000  185269500
# 2024-11-15 00:00:00+00:00  2540.0  2540.000000  103680400
# 2024-11-18 00:00:00+00:00  2590.0  2590.000000  119481300
#
# [1184 rows x 18 columns]

# %%
data.shape
# Out:
# (1184, 18)

# %%
# Check for any missing values
print(data.isnull().sum())
# Out:
# Ticker   Price
# ADRO.JK  Open         0
#          High         0
#          Low          0
#          Close        0
#          Adj Close    0
#          Volume       0
# BBCA.JK  Open         0
#          High         0
#          Low          0
#          Close        0
#          Adj Close    0
#          Volume       0
# TLKM.JK  Open         0
#          High         0
#          Low          0
#          Close        0
#          Adj Close    0
#          Volume       0
# dtype: int64

# %%
# Data Cleaning and Preprocessing
data = data.dropna()

# %%
# Check for any missing values
print(data.isnull().sum())
# Out:
# Ticker   Price
# ADRO.JK  Open         0
#          High         0
#          Low          0
#          Close        0
#          Adj Close    0
#          Volume       0
# BBCA.JK  Open         0
#          High         0
#          Low          0
#          Close        0
#          Adj Close    0
#          Volume       0
# TLKM.JK  Open         0
#          High         0
#          Low          0
#          Close        0
#          Adj Close    0
#          Volume       0
# dtype: int64

# %%
data.shape
# Out:
# (1184, 18)

# %%
data
# Out:
# Ticker                    ADRO.JK                                       \
# Price                        Open    High     Low   Close    Adj Close
# Date
# 2020-01-02 00:00:00+00:00  1555.0  1555.0  1490.0  1495.0   835.632263
# 2020-01-03 00:00:00+00:00  1460.0  1470.0  1425.0  1465.0   856.372131
# 2020-01-06 00:00:00+00:00  1455.0  1515.0  1450.0  1465.0   856.372131
# 2020-01-07 00:00:00+00:00  1480.0  1540.0  1460.0  1540.0   900.213867
# 2020-01-08 00:00:00+00:00  1530.0  1535.0  1505.0  1505.0   879.754395
# ...                           ...     ...     ...     ...          ...
# 2024-11-12 00:00:00+00:00  3800.0  3900.0  3790.0  3820.0  3820.000000
# 2024-11-13 00:00:00+00:00  3950.0  4010.0  3870.0  3920.0  3920.000000
# 2024-11-14 00:00:00+00:00  3940.0  3950.0  3830.0  3830.0  3830.000000
# 2024-11-15 00:00:00+00:00  3830.0  3940.0  3790.0  3920.0  3920.000000
# 2024-11-18 00:00:00+00:00  3920.0  3920.0  3670.0  3700.0  3700.000000
#
# Ticker                                BBCA.JK                             \
# Price                         Volume     Open     High      Low    Close
# Date
# 2020-01-02 00:00:00+00:00   76612000   6695.0   6780.0   6680.0   6690.0
# 2020-01-03 00:00:00+00:00  117795600   6750.0   6800.0   6725.0   6800.0
# 2020-01-06 00:00:00+00:00   61423200   6720.0   6750.0   6690.0   6735.0
# 2020-01-07 00:00:00+00:00   74336500   6735.0   6770.0   6730.0   6740.0
# 2020-01-08 00:00:00+00:00   55121100   6670.0   6745.0   6670.0   6680.0
# ...                              ...      ...      ...      ...      ...
# 2024-11-12 00:00:00+00:00   85754000  10100.0  10225.0  10000.0  10150.0
# 2024-11-13 00:00:00+00:00  144865000  10225.0  10250.0  10150.0  10150.0
# 2024-11-14 00:00:00+00:00   84790900  10125.0  10175.0  10050.0  10100.0
# 2024-11-15 00:00:00+00:00   83361300  10050.0  10275.0  10050.0  10175.0
# 2024-11-18 00:00:00+00:00  256319600  10075.0  10125.0  10000.0  10000.0
#
# Ticker                                            TLKM.JK                  \
# Price                         Adj Close    Volume    Open    High     Low
# Date
# 2020-01-02 00:00:00+00:00   6029.958008  49445000  3970.0  4000.0  3900.0
# 2020-01-03 00:00:00+00:00   6129.104492  47755500  3960.0  3980.0  3930.0
# 2020-01-06 00:00:00+00:00   6070.518066  27300000  3930.0  3970.0  3930.0
# 2020-01-07 00:00:00+00:00   6075.024414  45022500  3930.0  3970.0  3920.0
# 2020-01-08 00:00:00+00:00   6020.944336  53692500  3920.0  3950.0  3900.0
# ...                                 ...       ...     ...     ...     ...
# 2024-11-12 00:00:00+00:00  10150.000000  80378500  2660.0  2670.0  2600.0
# 2024-11-13 00:00:00+00:00  10150.000000  62933100  2610.0  2630.0  2570.0
# 2024-11-14 00:00:00+00:00  10100.000000  56381400  2550.0  2590.0  2530.0
# 2024-11-15 00:00:00+00:00  10175.000000  63598200  2500.0  2580.0  2500.0
# 2024-11-18 00:00:00+00:00  10000.000000  65716200  2540.0  2610.0  2520.0
#
# Ticker
# Price                       Close    Adj Close     Volume
# Date
# 2020-01-02 00:00:00+00:00  3910.0  3090.177979   52094000
# 2020-01-03 00:00:00+00:00  3980.0  3145.500977   70032900
# 2020-01-06 00:00:00+00:00  3960.0  3129.694092   42908900
# 2020-01-07 00:00:00+00:00  3940.0  3113.887939   51837600
# 2020-01-08 00:00:00+00:00  3900.0  3082.274658   52402600
# ...                           ...          ...        ...
# 2024-11-12 00:00:00+00:00  2600.0  2600.000000  215910600
# 2024-11-13 00:00:00+00:00  2580.0  2580.000000  142812600
# 2024-11-14 00:00:00+00:00  2530.0  2530.000000  185269500
# 2024-11-15 00:00:00+00:00  2540.0  2540.000000  103680400
# 2024-11-18 00:00:00+00:00  2590.0  2590.000000  119481300
#
# [1184 rows x 18 columns]

# %%
# Summary of data types
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1184 entries, 2020-01-02 00:00:00+00:00 to 2024-11-18 00:00:00+00:00
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (ADRO.JK, Open)       1184 non-null   float64
#  1   (ADRO.JK, High)       1184 non-null   float64
#  2   (ADRO.JK, Low)        1184 non-null   float64
#  3   (ADRO.JK, Close)      1184 non-null   float64
#  4   (ADRO.JK, Adj Close)  1184 non-null   float64
#  5   (ADRO.JK, Volume)     1184 non-null   int64
#  6   (BBCA.JK, Open)       1184 non-null   float64
#  7   (BBCA.JK, High)       1184 non-null   float64
#  8   (BBCA.JK, Low)        1184 non-null   float64
#  9   (BBCA.JK, Close)      1184 non-null   float64
#  10  (BBCA.JK, Adj Close)  1184 non-null   float64
#  11  (BBCA.JK, Volume)     1184 non-null   int64
#  12  (TLKM.JK, Open)       1184 non-null   float64
#  13  (TLKM.JK, High)       1184 non-null   float64
#  14  (TLKM.JK, Low)        1184 non-null   float64
#  15  (TLKM.JK, Close)      1184 non-null   float64
#  16  (TLKM.JK, Adj Close)  1184 non-null   float64
#  17  (TLKM.JK, Volume)     1184 non-null   int64
# dtypes: float64(15), int64(3)
# memory usage: 175.8 KB
# None

# %%
# Get summary statistics for numerical columns
data.describe()
# Out:
# Ticker      ADRO.JK                                                      \
# Price          Open         High          Low        Close    Adj Close
# count   1184.000000  1184.000000  1184.000000  1184.000000  1184.000000
# mean    2288.019426  2325.080236  2249.184966  2284.864865  1775.971974
# std      940.369831   951.662365   929.005635   940.328659   925.624351
# min      645.000000   670.000000   610.000000   645.000000   377.037628
# 25%     1280.000000  1305.000000  1255.000000  1283.750000   789.839844
# 50%     2420.000000  2460.000000  2390.000000  2420.000000  2035.402222
# 75%     2960.000000  3020.000000  2902.500000  2950.000000  2412.473694
# max     4140.000000  4300.000000  4080.000000  4140.000000  4040.000000
#
# Ticker                     BBCA.JK                                            \
# Price         Volume          Open          High           Low         Close
# count   1.184000e+03   1184.000000   1184.000000   1184.000000   1184.000000
# mean    8.788703e+07   7868.462838   7939.417230   7794.978885   7866.254223
# std     6.889833e+07   1481.945117   1481.922827   1485.955688   1486.176871
# min     0.000000e+00   4450.000000   4800.000000   4325.000000   4430.000000
# 25%     4.291208e+07   6555.000000   6590.000000   6500.000000   6565.000000
# 50%     7.003040e+07   7825.000000   7900.000000   7750.000000   7862.500000
# 75%     1.072791e+08   9050.000000   9125.000000   9025.000000   9050.000000
# max     5.399952e+08  10900.000000  10950.000000  10775.000000  10950.000000
#
# Ticker                                  TLKM.JK                            \
# Price      Adj Close        Volume         Open         High          Low
# count    1184.000000  1.184000e+03  1184.000000  1184.000000  1184.000000
# mean     7505.016884  8.819083e+07  3633.471284  3673.403716  3589.873311
# std      1632.985543  5.771252e+07   517.547727   517.338091   516.423654
# min      3992.931396  0.000000e+00  2500.000000  2580.000000  2450.000000
# 25%      6057.130371  5.693132e+07  3190.000000  3230.000000  3140.000000
# 50%      7392.186523  7.536235e+07  3690.000000  3730.000000  3665.000000
# 75%      8828.464844  1.026075e+08  4020.000000  4050.000000  3980.000000
# max     10950.000000  7.564316e+08  4850.000000  4850.000000  4720.000000
#
# Ticker
# Price         Close    Adj Close        Volume
# count   1184.000000  1184.000000  1.184000e+03
# mean    3630.126689  3230.809976  1.168823e+08
# std      519.373184   514.524176  7.798909e+07
# min     2530.000000  2070.656006  0.000000e+00
# 25%     3180.000000  2815.622314  6.943402e+07
# 50%     3690.000000  3259.320801  9.674090e+07
# 75%     4020.000000  3673.609009  1.406092e+08
# max     4770.000000  4295.701172  1.155861e+09

# %% [markdown]
# ## EDA
# - Closing Price
# - Close Price and 30-Day Moving Average
# - Correlation between Stocks
# - Daily Return
# - Monthly and Yearly Average Closing Price

# %%
# EDA

import matplotlib.pyplot as plt

# Plot closing prices for each ticker
for ticker in ticker_symbols:
    plt.figure(figsize=(12, 6))
    data[ticker]['Close'].plot(title=f'{ticker} Closing Prices')
    plt.xlabel('Date')
    plt.ylabel('Closing Price')
    plt.show()

# %%
# Create a dictionary to hold the data with moving averages
ma_data = {}

for ticker in ticker_symbols:
    # Extract close prices for the ticker and calculate the 30-day moving average
    close_prices = data[ticker]['Close']
    ma_data[ticker] = pd.DataFrame({
        'Close': close_prices,
        'MA30': close_prices.rolling(window=30).mean()
    })

    # Plot close prices and 30-day moving average
    plt.figure(figsize=(12, 6))
    plt.plot(ma_data[ticker]['Close'], label='Closing Price')
    plt.plot(ma_data[ticker]['MA30'], label='30-Day Moving Average')
    plt.title(f'{ticker} - Close Price and 30-Day Moving Average')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %%
# Extract closing prices of all tickers
close_prices = pd.DataFrame({ticker: data[ticker]['Close'] for ticker in ticker_symbols})

# Calculate correlation matrix
correlation_matrix = close_prices.corr()
print("Correlation Matrix:\n", correlation_matrix)

# Heatmap of the correlation matrix
import seaborn as sns
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation between Stocks')
plt.show()
# Out:
# Correlation Matrix:
#            ADRO.JK   BBCA.JK   TLKM.JK
# ADRO.JK  1.000000  0.800619  0.442984
# BBCA.JK  0.800619  1.000000  0.216470
# TLKM.JK  0.442984  0.216470  1.000000

# %%
# Calculate daily returns
returns = close_prices.pct_change()

# Plot the daily returns
for ticker in ticker_symbols:
    plt.figure(figsize=(12, 6))
    returns[ticker].plot(title=f'{ticker} Daily Returns')
    plt.xlabel('Date')
    plt.ylabel('Daily Return')
    plt.show()

# Calculate volatility (standard deviation of returns)
volatility = returns.std()
print("Volatility:\n")
print(volatility)
# Out:
# Volatility:
#
# ADRO.JK    0.028306
# BBCA.JK    0.016211
# TLKM.JK    0.018907
# dtype: float64

# %%
# Resample to monthly mean
monthly_prices = close_prices.resample('ME').mean()
monthly_prices.plot(figsize=(14, 7), title='Monthly Average Closing Prices')
plt.xlabel('Date')
plt.ylabel('Monthly Average Price')
plt.show()

# Resample to yearly mean
yearly_prices = close_prices.resample('YE').mean()
yearly_prices.plot(figsize=(14, 7), title='Yearly Average Closing Prices')
plt.xlabel('Year')
plt.ylabel('Yearly Average Price')
plt.show()

# %% [markdown]
# ## Targets and Features Engineering

# %%
# All columns

print(data.columns)
# Therea are 2 columns for indexes: Ticker & Price
# Out:
# MultiIndex([('ADRO.JK',      'Open'),
#             ('ADRO.JK',      'High'),
#             ('ADRO.JK',       'Low'),
#             ('ADRO.JK',     'Close'),
#             ('ADRO.JK', 'Adj Close'),
#             ('ADRO.JK',    'Volume'),
#             ('BBCA.JK',      'Open'),
#             ('BBCA.JK',      'High'),
#             ('BBCA.JK',       'Low'),
#             ('BBCA.JK',     'Close'),
#             ('BBCA.JK', 'Adj Close'),
#             ('BBCA.JK',    'Volume'),
#             ('TLKM.JK',      'Open'),
#             ('TLKM.JK',      'High'),
#             ('TLKM.JK',       'Low'),
#             ('TLKM.JK',     'Close'),
#             ('TLKM.JK', 'Adj Close'),
#             ('TLKM.JK',    'Volume')],
#            names=['Ticker', 'Price'])

# %%
for ticker in ticker_symbols:
    ticker_feature_canditates = [col for col in data.columns if ticker in col and 'target' not in col]    
    print(ticker_feature_canditates)
# Out:
# [('ADRO.JK', 'Open'), ('ADRO.JK', 'High'), ('ADRO.JK', 'Low'), ('ADRO.JK', 'Close'), ('ADRO.JK', 'Adj Close'), ('ADRO.JK', 'Volume')]
# [('BBCA.JK', 'Open'), ('BBCA.JK', 'High'), ('BBCA.JK', 'Low'), ('BBCA.JK', 'Close'), ('BBCA.JK', 'Adj Close'), ('BBCA.JK', 'Volume')]
# [('TLKM.JK', 'Open'), ('TLKM.JK', 'High'), ('TLKM.JK', 'Low'), ('TLKM.JK', 'Close'), ('TLKM.JK', 'Adj Close'), ('TLKM.JK', 'Volume')]

# %%
# Define columns format 
data.columns = ['_'.join(col).replace(' ', '') for col in data.columns]
print(data.columns)
# Out:
# Index(['ADRO.JK_Open', 'ADRO.JK_High', 'ADRO.JK_Low', 'ADRO.JK_Close',
#        'ADRO.JK_AdjClose', 'ADRO.JK_Volume', 'BBCA.JK_Open', 'BBCA.JK_High',
#        'BBCA.JK_Low', 'BBCA.JK_Close', 'BBCA.JK_AdjClose', 'BBCA.JK_Volume',
#        'TLKM.JK_Open', 'TLKM.JK_High', 'TLKM.JK_Low', 'TLKM.JK_Close',
#        'TLKM.JK_AdjClose', 'TLKM.JK_Volume'],
#       dtype='object')

# %%
# Features and Target Engineering
# Add 30-day Moving Average (MA30) for each ticker
data = data.copy()  # Ensure data is a full copy, not a view

for ticker in ticker_symbols:
    close_col = f"{ticker}_Close"
    ma_col = f"{ticker}_MA30"
    data[ma_col] = data[close_col].rolling(window=30).mean()

print(data.columns)
# Out:
# Index(['ADRO.JK_Open', 'ADRO.JK_High', 'ADRO.JK_Low', 'ADRO.JK_Close',
#        'ADRO.JK_AdjClose', 'ADRO.JK_Volume', 'BBCA.JK_Open', 'BBCA.JK_High',
#        'BBCA.JK_Low', 'BBCA.JK_Close', 'BBCA.JK_AdjClose', 'BBCA.JK_Volume',
#        'TLKM.JK_Open', 'TLKM.JK_High', 'TLKM.JK_Low', 'TLKM.JK_Close',
#        'TLKM.JK_AdjClose', 'TLKM.JK_Volume', 'ADRO.JK_MA30', 'BBCA.JK_MA30',
#        'TLKM.JK_MA30'],
#       dtype='object')

# %%
# Define Targets and Features for every Ticker

ticker_symbols = ['ADRO.JK', 'BBCA.JK', 'TLKM.JK']
targets = ['UpdDown', 'DailyResult', 'Votality']

for ticker in ticker_symbols:
    for target in targets:
        match target:
            case 'UpdDown':
                features = f'{ticker}_Open, {ticker}_Close, {ticker}_Volume, {ticker}_MA30'
            case 'DailyResult':
                features = f'{ticker}_MA30, {ticker}_High, {ticker}_Low, {ticker}_Volume'
            case 'Votality':
                features = f'{ticker}_MA30, {ticker}_Volume, {ticker}_Open'
            case _:
                features = "Unknown target"
        
        print(f'\nFeatures for {ticker} with target {target}:')
        print(features)
# Out:
# Features for ADRO.JK with target UpdDown:
# ADRO.JK_Open, ADRO.JK_Close, ADRO.JK_Volume, ADRO.JK_MA30
#
# Features for ADRO.JK with target DailyResult:
# ADRO.JK_MA30, ADRO.JK_High, ADRO.JK_Low, ADRO.JK_Volume
#
# Features for ADRO.JK with target Votality:
# ADRO.JK_MA30, ADRO.JK_Volume, ADRO.JK_Open
#
# Features for BBCA.JK with target UpdDown:
# BBCA.JK_Open, BBCA.JK_Close, BBCA.JK_Volume, BBCA.JK_MA30
#
# Features for BBCA.JK with target DailyResult:
# BBCA.JK_MA30, BBCA.JK_High, BBCA.JK_Low, BBCA.JK_Volume
#
# Features for BBCA.JK with target Votality:
# BBCA.JK_MA30, BBCA.JK_Volume, BBCA.JK_Open
#
# Features for TLKM.JK with target UpdDown:
# TLKM.JK_Open, TLKM.JK_Close, TLKM.JK_Volume, TLKM.JK_MA30
#
# Features for TLKM.JK with target DailyResult:
# TLKM.JK_MA30, TLKM.JK_High, TLKM.JK_Low, TLKM.JK_Volume
#
# Features for TLKM.JK with target Votality:
# TLKM.JK_MA30, TLKM.JK_Volume, TLKM.JK_Open
